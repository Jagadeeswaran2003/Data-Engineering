# %%
import os
import json
import requests

import pandas as pd

from scrapy import Selector
from tqdm.notebook import tqdm

# %%
filename = "D:/ME204/Plum Project/Data/Raw/Plum_Project_Uncleaning.csv"
Plum_Project = pd.read_csv(filename)

# %%
Plum_Project
# Out:
#                                      Name_of_Products     Prices Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water    ₹849.00      ₹738.00
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...    ₹399.00      ₹849.00
# 2               2% Niacinamide & Rice Water Gel Cream    ₹525.00      ₹347.00
# 3   Niacinamide Clear & Bright Skin Combo | With N...  ₹1,993.00      ₹399.00
# 4           3% Niacinamide Face Toner with Rice Water    ₹420.00      ₹456.00
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...    ₹799.00      ₹525.00
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...    ₹699.00    ₹1,494.00
# 7          15% Vitamin C Serum for Face with Mandarin    ₹790.00    ₹1,993.00
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...    ₹499.00      ₹390.00
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...    ₹499.00      ₹420.00
# 10  2% Niacinamide & Rice Water Simply Bright Face...    ₹299.00      ₹695.00
# ...

# %%
def convert_price(Price):
    try:
        return float(Price.replace("₹", " "))
    except:
        return None

Plum_Project["Prices"] = Plum_Project["Prices"].apply(convert_price)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0      ₹738.00
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0      ₹849.00
# 2               2% Niacinamide & Rice Water Gel Cream   525.0      ₹347.00
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN      ₹399.00
# 4           3% Niacinamide Face Toner with Rice Water   420.0      ₹456.00
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0      ₹525.00
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0    ₹1,494.00
# 7          15% Vitamin C Serum for Face with Mandarin   790.0    ₹1,993.00
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0      ₹390.00
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0      ₹420.00
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0      ₹695.00
# ...

# %%
def convert_offer_price(Offer_Price):
    try:
        return float(Offer_Price.replace("₹", " "))
    except:
        return None
Plum_Project["Offer_Prices"] = Plum_Project["Offer_Prices"].apply(convert_price)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0         738.0
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0         849.0
# 2               2% Niacinamide & Rice Water Gel Cream   525.0         347.0
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN         399.0
# 4           3% Niacinamide Face Toner with Rice Water   420.0         456.0
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0         525.0
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0           NaN
# 7          15% Vitamin C Serum for Face with Mandarin   790.0           NaN
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0         390.0
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0         420.0
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0         695.0
# ...

# %%
def convert_rating(Rating):
    try:
        return float(Rating.replace("★", " "))
    except:
        return None

Plum_Project["Ratings"] = Plum_Project["Ratings"].apply(convert_rating)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0         738.0
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0         849.0
# 2               2% Niacinamide & Rice Water Gel Cream   525.0         347.0
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN         399.0
# 4           3% Niacinamide Face Toner with Rice Water   420.0         456.0
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0         525.0
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0           NaN
# 7          15% Vitamin C Serum for Face with Mandarin   790.0           NaN
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0         390.0
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0         420.0
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0         695.0
# ...

# %%
def convert_benefit(Benefit):
    try:
        return str(Benefit.replace("\n", " "))
    except:
        return None

Plum_Project["Benefits"] = Plum_Project["Benefits"].apply(convert_benefit)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0         738.0
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0         849.0
# 2               2% Niacinamide & Rice Water Gel Cream   525.0         347.0
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN         399.0
# 4           3% Niacinamide Face Toner with Rice Water   420.0         456.0
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0         525.0
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0           NaN
# 7          15% Vitamin C Serum for Face with Mandarin   790.0           NaN
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0         390.0
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0         420.0
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0         695.0
# ...

# %%
def convert_position(Position):
    try:
        return str(Position.replace("🔥", " "))
    except:
        return None

Plum_Project["Positions"] = Plum_Project["Positions"].apply(convert_position)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0         738.0
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0         849.0
# 2               2% Niacinamide & Rice Water Gel Cream   525.0         347.0
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN         399.0
# 4           3% Niacinamide Face Toner with Rice Water   420.0         456.0
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0         525.0
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0           NaN
# 7          15% Vitamin C Serum for Face with Mandarin   790.0           NaN
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0         390.0
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0         420.0
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0         695.0
# ...

# %%
def convert_review(Reviews):
    try:
        return int(Reviews.replace("reviews", " "))
    except:
        return None

Plum_Project["Reviews"] = Plum_Project["Reviews"].apply(convert_review)

# %%
Plum_Project
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water   849.0         738.0
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...   399.0         849.0
# 2               2% Niacinamide & Rice Water Gel Cream   525.0         347.0
# 3   Niacinamide Clear & Bright Skin Combo | With N...     NaN         399.0
# 4           3% Niacinamide Face Toner with Rice Water   420.0         456.0
# 5   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...   799.0         525.0
# 6   Plum Oat & Ceramide Complex 100% Mineral Sunsc...   699.0           NaN
# 7          15% Vitamin C Serum for Face with Mandarin   790.0           NaN
# 8   Rice water & 3% Niacinamide sheer-tinted sunsc...   499.0         390.0
# 9   Bulgarian Rose and 1% Hyaluronic Acid Dew-it-l...   499.0         420.0
# 10  2% Niacinamide & Rice Water Simply Bright Face...   299.0         695.0
# ...

# %%
Plum_Project_cleaning = "D:/ME204/Plum Project/Data/Clean/Plum_Project_Data.csv"
Plum_Project_cleaning = pd.read_csv(Plum_Project_cleaning)

# %%
Plum_Project_cleaning
# Out:
#                                      Name_of_Products  Prices  Offer_Prices  \
# 0      10% Niacinamide Serum for Face with Rice Water     849           679
# 1   2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...     599           849
# 2               2% Niacinamide & Rice Water Gel Cream     525           479
# 3           3% Niacinamide Face Toner with Rice Water     555           420
# 4   Cica & Hya-Betaine Vegan Mucin Face Essence Wi...     799           525
# 5   Rice water & 3% Niacinamide sheer-tinted sunsc...     499           336
# 6   2% Niacinamide & Rice Water Simply Bright Face...     299           420
# 7   Green Tea & Zinc Super-Matte Sunscreen Gel | S...     575           639
# 8                  Green Tea Pore Cleansing Face Wash     350           799
# 9           Oat & 1% Ceramide Barrier Love Face Cream     399           594
# 10  2% Niacinamide & Rice Water SPF 50 PA+++ Hybri...     798           632
# ...
